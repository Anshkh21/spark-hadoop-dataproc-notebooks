# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
.appName('Sql')\
.config("spark.sql.warehouse.dir", "/tmp/spark-warehouse")\
.enableHiveSupport()\
.getOrCreate()
# Out:
# 25/12/24 13:44:55 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
data = [
    (1, "John Doe", "Bangalore", "2023-01-15", "152.75", "True"),
    (2, "Jane Smith", "Delhi", "2023-05-20", "89.50", "False"),
    (3, "Robert Brown", "Mumbai", "InvalidDate", "200.00", "True")
]

columns = ["id", "name", "city", "date", "amount", "is_active"]

df = spark.createDataFrame(data,schema=columns)

# %%
df.show()
# Out:
# +---+------------+---------+-----------+------+---------+
# | id|        name|     city|       date|amount|is_active|
# +---+------------+---------+-----------+------+---------+
# |  1|    John Doe|Bangalore| 2023-01-15|152.75|     True|
# |  2|  Jane Smith|    Delhi| 2023-05-20| 89.50|    False|
# |  3|Robert Brown|   Mumbai|InvalidDate|200.00|     True|
# +---+------------+---------+-----------+------+---------+

# %%
spark.sql('show databases').show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql('show tables').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default|cust_pers|      false|
# +---------+---------+-----------+

# %%
spark.sql('select * from cust_pers limit 5').show()
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    false|
# |          1|Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     true|
# |          2|Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     true|
# |          3|Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    false|
# |          4|Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    false|
# +-----------+----------+---------+-----------+-------+-----------------+---------+

# %%
spark.stop()
