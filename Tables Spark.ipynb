# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
.appName('Spark Tables')\
.enableHiveSupport()\
.getOrCreate()

# %%
# !hadoop fs -ls /data/
# Out:
# Found 3 items
# -rw-r--r--   2 root hadoop       5488 2025-12-20 19:02 /data/customers_100.csv
# -rw-r--r--   2 root hadoop        210 2025-12-22 13:34 /data/dates_data.csv
# drwxr-xr-x   - root hadoop          0 2025-12-20 20:26 /data/write_output.csv

# %%
df = spark.read \
.format('csv')\
.option('header','True')\
.option('inferSchema','True')\
.load('/data/customers_100.csv')

# %%
df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    false|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     true|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     true|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    false|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    false|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    false|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    false|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     true|
# |          8| Customer_8|     Pune|  Karnataka|  India|       2023-06-22|     true|
# |          9| Customer_9|   Mumbai|  Telangana|  India|       2023-01-05|     true|
# |         10|Customer_10|     Pune|    Gujarat|  India|       2023-08-05|     true|
# |         11|Customer_11|    Delhi|West Bengal|  India|       2023-08-02|    false|
# |         12|Customer_12|  Chennai|    Gujarat|  India|       2023-11-21|    false|
# |         13|Customer_13|  Chennai|  Karnataka|  India|       2023-11-06|     true|
# |         14|Customer_14|Hyderabad| Tamil Nadu|  India|       2023-02-07|    false|
# |         15|Customer_15|   Mumbai|    Gujarat|  India|       2023-03-02|     true|
# |         16|Customer_16|  Chennai|  Karnataka|  India|       2023-04-05|    false|
# |         17|Customer_17|Hyderabad|West Bengal|  India|       2023-08-21|    false|
# |         18|Customer_18|     Pune|      Delhi|  India|       2023-10-04|     true|
# |         19|Customer_19|  Kolkata|    Gujarat|  India|       2023-02-05|     true|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# only showing top 20 rows

# %%
spark.sql('show tables').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# +---------+---------+-----------+

# %%
df.createOrReplaceTempView('temp_cust')

# %%
spark.sql('show tables').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |         |temp_cust|       true|
# +---------+---------+-----------+

# %%
spark.sql('select * from temp_cust limit 5').show()
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    false|
# |          1|Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     true|
# |          2|Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     true|
# |          3|Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    false|
# |          4|Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    false|
# +-----------+----------+---------+-----------+-------+-----------------+---------+

# %%
df.createOrReplaceGlobalTempView('temp_cust')

# %%
spark.sql('show tables in global_temp').show()
# Out:
# +-----------+---------+-----------+
# |  namespace|tableName|isTemporary|
# +-----------+---------+-----------+
# |global_temp|temp_cust|       true|
# |           |temp_cust|       true|
# +-----------+---------+-----------+

# %%
spark.sql('select * from global_temp.temp_cust limit 5').show()
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    false|
# |          1|Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     true|
# |          2|Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     true|
# |          3|Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    false|
# |          4|Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    false|
# +-----------+----------+---------+-----------+-------+-----------------+---------+

# %%
spark.sql('drop table global_temp.temp_cust')
# Out:
# DataFrame[]

# %%
spark.sql('show tables in global_temp').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |         |temp_cust|       true|
# +---------+---------+-----------+

# %%
# Persistent table

# %%
 df.write.mode('overwrite').saveAsTable('cust_pers')
# Out:
# 25/12/23 21:44:57 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %%
spark.sql('show tables').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default|cust_pers|      false|
# |         |temp_cust|       true|
# +---------+---------+-----------+

# %%
spark_new = spark.newSession()

# %%
spark_new.sparkContext.applicationId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 spark_new.sparkContext.applicationId
#
# File /usr/lib/spark/python/pyspark/context.py:585, in SparkContext.applicationId(self)
#     569 @property
#     570 def applicationId(self) -> str:
#     571     """
#     572     A unique identifier for the Spark application.
#     573     Its format depends on the scheduler implementation.
#    (...)
#     583     'local-...'
#     584     """
# --> 585     return self._jsc.sc().applicationId()
#
# AttributeError: 'NoneType' object has no attribute 'sc'

# %%
spark.sparkContext.applicationId
# Out:
# 'application_1766520098500_0012'

# %%
spark_new.sql('show tables').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default|cust_pers|      false|
# +---------+---------+-----------+

# %%
spark.sql('show tables').show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default|cust_pers|      false|
# |         |temp_cust|       true|
# +---------+---------+-----------+

# %%
spark.sql('describe cust_pers').show()
# Out:
# +-----------------+---------+-------+
# |         col_name|data_type|comment|
# +-----------------+---------+-------+
# |      customer_id|      int|   NULL|
# |             name|   string|   NULL|
# |             city|   string|   NULL|
# |            state|   string|   NULL|
# |          country|   string|   NULL|
# |registration_date|     date|   NULL|
# |        is_active|  boolean|   NULL|
# +-----------------+---------+-------+

# %%
spark.sql('describe extended cust_pers').show(truncate=False)
# Out:
# +----------------------------+-------------------------------------------+-------+
# |col_name                    |data_type                                  |comment|
# +----------------------------+-------------------------------------------+-------+
# |customer_id                 |int                                        |NULL   |
# |name                        |string                                     |NULL   |
# |city                        |string                                     |NULL   |
# |state                       |string                                     |NULL   |
# |country                     |string                                     |NULL   |
# |registration_date           |date                                       |NULL   |
# |is_active                   |boolean                                    |NULL   |
# |                            |                                           |       |
# |# Detailed Table Information|                                           |       |
# |Catalog                     |spark_catalog                              |       |
# |Database                    |default                                    |       |
# |Table                       |cust_pers                                  |       |
# |Owner                       |root                                       |       |
# |Created Time                |Tue Dec 23 21:44:58 UTC 2025               |       |
# |Last Access                 |UNKNOWN                                    |       |
# |Created By                  |Spark 3.5.3                                |       |
# |Type                        |MANAGED                                    |       |
# |Provider                    |parquet                                    |       |
# |Statistics                  |3625 bytes                                 |       |
# |Location                    |hdfs://test-m/user/hive/warehouse/cust_pers|       |
# +----------------------------+-------------------------------------------+-------+
# only showing top 20 rows

# %%
spark_new.stop()

# %%
spark.stop()
