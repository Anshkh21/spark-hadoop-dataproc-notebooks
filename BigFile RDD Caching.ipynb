# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
.appName('Caching BigFile')\
.master('yarn')\
.getOrCreate()
# Out:
# 25/12/29 14:36:31 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# !hadoop fs -ls gs://anshk-data/Data/300MB/
# Out:
# 2025-12-29 14:38:46,030 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-12-29 14:38:46,120 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-12-29 14:38:46,120 INFO impl.MetricsSystemImpl: google-hadoop-file-system metrics system started
# Found 5 items
# -rwx------   3 root root  343317147 2025-12-15 13:12 gs://anshk-data/Data/300MB/customers.csv
# -rwx------   3 root root  288701152 2025-12-15 13:10 gs://anshk-data/Data/300MB/items.csv
# -rwx------   3 root root  284122744 2025-12-15 13:10 gs://anshk-data/Data/300MB/orders.csv
# -rwx------   3 root root  281465270 2025-12-15 13:20 gs://anshk-data/Data/300MB/payments.csv
# -rwx------   3 root root  268943617 2025-12-15 13:19 gs://anshk-data/Data/300MB/shippings.csv

# %%
customers_rdd = spark.sparkContext.textFile('gs://anshk-data/Data/300MB/customers.csv')

# %%
customers_filtered = customers_rdd.filter(lambda row:'Mumbai' in row)
customers_mapped = customers_filtered.map(lambda row:(row.split(',')[0],1))
customers_reduced = customers_mapped.reduceByKey(lambda x,y:x+y)

# %%
customers_reduced.count()
# Out:
# 661241

# %%
customers_reduced.count()
# Out:
# 661241

# %%
customers_reduced.cache()
# Out:
# PythonRDD[8] at RDD at PythonRDD.scala:53

# %%
customers_reduced.count()
# Out:
# 661241

# %%
customers_reduced.count()
# Out:
# 661241

# %%
customers_reduced.count()
# Out:
# 661241

# %%
customers_reduced.count()
# Out:
# 661241

# %%
customers_reduced.unpersist()
# Out:
# PythonRDD[8] at RDD at PythonRDD.scala:53

# %%
spark.stop()
