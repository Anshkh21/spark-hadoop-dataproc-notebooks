# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
.appName('DF_cache')\
.getOrCreate()
# Out:
# 25/12/29 15:21:57 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# !hadoop fs -ls /data
# Out:
# Found 3 items
# -rw-r--r--   2 root hadoop       5488 2025-12-20 19:02 /data/customers_100.csv
# -rw-r--r--   2 root hadoop        210 2025-12-22 13:34 /data/dates_data.csv
# drwxr-xr-x   - root hadoop          0 2025-12-20 20:26 /data/write_output.csv

# %%
customers_df = spark.read.option('header','true').csv('/data/customers_100.csv')

# %%
customers_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    False|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     True|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     True|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    False|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    False|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    False|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    False|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     True|
# ...

# %%
customers_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- registration_date: string (nullable = true)
#  |-- is_active: string (nullable = true)

# %%
customers_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    False|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     True|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     True|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    False|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    False|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    False|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    False|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     True|
# ...

# %%
customers_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    False|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     True|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     True|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    False|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    False|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    False|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    False|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     True|
# ...

# %%
customers_df.cache()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    False|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     True|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     True|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    False|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    False|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    False|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    False|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     True|
# ...

# %%
customers_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    False|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     True|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     True|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    False|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    False|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    False|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    False|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     True|
# ...

# %%
customers_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          0| Customer_0|     Pune|Maharashtra|  India|       2023-06-29|    False|
# |          1| Customer_1|Bangalore| Tamil Nadu|  India|       2023-12-07|     True|
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2023-10-27|     True|
# |          3| Customer_3|Bangalore|  Karnataka|  India|       2023-10-17|    False|
# |          4| Customer_4|Ahmedabad|  Karnataka|  India|       2023-03-14|    False|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2023-07-28|    False|
# |          6| Customer_6|     Pune|      Delhi|  India|       2023-08-29|    False|
# |          7| Customer_7|Ahmedabad|West Bengal|  India|       2023-12-28|     True|
# ...

# %%
tail_df = customers_df.orderBy('customer_id',ascending=False)

# %%
tail_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |         98|Customer_98|     Pune|West Bengal|  India|       2023-06-01|     True|
# |         97|Customer_97|     Pune|Maharashtra|  India|       2023-10-31|     True|
# |         96|Customer_96|Ahmedabad|  Telangana|  India|       2023-06-22|    False|
# |         95|Customer_95|   Mumbai|  Karnataka|  India|       2023-09-29|     True|
# |         94|Customer_94|  Chennai|Maharashtra|  India|       2023-04-28|    False|
# |         93|Customer_93|     Pune|West Bengal|  India|       2023-09-30|    False|
# |         92|Customer_92|  Kolkata|      Delhi|  India|       2023-06-25|     True|
# |         91|Customer_91|   Mumbai|  Telangana|  India|       2023-01-02|    False|
# ...

# %%
tail_df.cache()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
tail_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |         98|Customer_98|     Pune|West Bengal|  India|       2023-06-01|     True|
# |         97|Customer_97|     Pune|Maharashtra|  India|       2023-10-31|     True|
# |         96|Customer_96|Ahmedabad|  Telangana|  India|       2023-06-22|    False|
# |         95|Customer_95|   Mumbai|  Karnataka|  India|       2023-09-29|     True|
# |         94|Customer_94|  Chennai|Maharashtra|  India|       2023-04-28|    False|
# |         93|Customer_93|     Pune|West Bengal|  India|       2023-09-30|    False|
# |         92|Customer_92|  Kolkata|      Delhi|  India|       2023-06-25|     True|
# |         91|Customer_91|   Mumbai|  Telangana|  India|       2023-01-02|    False|
# ...

# %%
tail_df.show()
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |         98|Customer_98|     Pune|West Bengal|  India|       2023-06-01|     True|
# |         97|Customer_97|     Pune|Maharashtra|  India|       2023-10-31|     True|
# |         96|Customer_96|Ahmedabad|  Telangana|  India|       2023-06-22|    False|
# |         95|Customer_95|   Mumbai|  Karnataka|  India|       2023-09-29|     True|
# |         94|Customer_94|  Chennai|Maharashtra|  India|       2023-04-28|    False|
# |         93|Customer_93|     Pune|West Bengal|  India|       2023-09-30|    False|
# |         92|Customer_92|  Kolkata|      Delhi|  India|       2023-06-25|     True|
# |         91|Customer_91|   Mumbai|  Telangana|  India|       2023-01-02|    False|
# ...

# %%
customers_df.count()
# Out:
# 99

# %%
filtered_df = customers_df.filter(customers_df.city=='Mumbai')

# %%
filtered_df.show()
# Out:
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |customer_id|       name|  city|      state|country|registration_date|is_active|
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |          9| Customer_9|Mumbai|  Telangana|  India|       2023-01-05|     True|
# |         15|Customer_15|Mumbai|    Gujarat|  India|       2023-03-02|     True|
# |         33|Customer_33|Mumbai|West Bengal|  India|       2023-09-11|    False|
# |         60|Customer_60|Mumbai| Tamil Nadu|  India|       2023-12-01|     True|
# |         63|Customer_63|Mumbai|  Karnataka|  India|       2023-05-23|     True|
# |         71|Customer_71|Mumbai|West Bengal|  India|       2023-12-19|     True|
# |         72|Customer_72|Mumbai|Maharashtra|  India|       2023-09-20|    False|
# |         91|Customer_91|Mumbai|  Telangana|  India|       2023-01-02|    False|
# |         95|Customer_95|Mumbai|  Karnataka|  India|       2023-09-29|     True|
# ...

# %%
filtered_df.cache()
# Out:
# 25/12/29 18:44:55 WARN CacheManager: Asked to cache already cached data.
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
tail_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
filtered_df.show()
# Out:
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |customer_id|       name|  city|      state|country|registration_date|is_active|
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |          9| Customer_9|Mumbai|  Telangana|  India|       2023-01-05|     True|
# |         15|Customer_15|Mumbai|    Gujarat|  India|       2023-03-02|     True|
# |         33|Customer_33|Mumbai|West Bengal|  India|       2023-09-11|    False|
# |         60|Customer_60|Mumbai| Tamil Nadu|  India|       2023-12-01|     True|
# |         63|Customer_63|Mumbai|  Karnataka|  India|       2023-05-23|     True|
# |         71|Customer_71|Mumbai|West Bengal|  India|       2023-12-19|     True|
# |         72|Customer_72|Mumbai|Maharashtra|  India|       2023-09-20|    False|
# |         91|Customer_91|Mumbai|  Telangana|  India|       2023-01-02|    False|
# |         95|Customer_95|Mumbai|  Karnataka|  India|       2023-09-29|     True|
# ...

# %%
filtered_df.show()
# Out:
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |customer_id|       name|  city|      state|country|registration_date|is_active|
# +-----------+-----------+------+-----------+-------+-----------------+---------+
# |          9| Customer_9|Mumbai|  Telangana|  India|       2023-01-05|     True|
# |         15|Customer_15|Mumbai|    Gujarat|  India|       2023-03-02|     True|
# |         33|Customer_33|Mumbai|West Bengal|  India|       2023-09-11|    False|
# |         60|Customer_60|Mumbai| Tamil Nadu|  India|       2023-12-01|     True|
# |         63|Customer_63|Mumbai|  Karnataka|  India|       2023-05-23|     True|
# |         71|Customer_71|Mumbai|West Bengal|  India|       2023-12-19|     True|
# |         72|Customer_72|Mumbai|Maharashtra|  India|       2023-09-20|    False|
# |         91|Customer_91|Mumbai|  Telangana|  India|       2023-01-02|    False|
# |         95|Customer_95|Mumbai|  Karnataka|  India|       2023-09-29|     True|
# ...

# %%
filtered_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
spark.stop()
